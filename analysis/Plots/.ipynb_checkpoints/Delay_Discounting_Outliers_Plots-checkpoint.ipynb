# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt
pd.set_option('display.max_columns', 2000)
# %matplotlib inline
dmt = pd.read_csv('../data/DMT_Data_Merged_10.25.17.csv')

# %%
dmt.head()
# Out:
#    internalId externalId passive_phone_model  passive_bat_charge_avg  \
# 0       70052     2w4MVh                 NaN                     NaN
# 1       70061     2XdEfU              iPhone                6.835596
# 2       70087     2XyVyJ                 NaN                     NaN
# 3       70074     34fjYg                 NaN                     NaN
# 4       70133     3FGrfL                 NaN                     NaN
#
#    passive_bat_charge_less_5hr  passive_bat_charge_start_mean  \
# 0                          NaN                            NaN
# 1                     0.708333                      52.611111
# 2                          NaN                            NaN
# 3                          NaN                            NaN
# 4                          NaN                            NaN
#
#    passive_bat_charge_end_mean  passive_bat_charge_increase_mean  \
# 0                          NaN                               NaN
# ...

# %% [markdown]
# ### Sage

# %%
#Outlier analysis for time variables (times shown in seconds).
for col in dmt.columns:
    if 'delay' in col and ('times_v' in col or 'times_mean' in col):
        times = dmt[col] / 1000
        print(times.describe())
        pd.Series(times).plot.hist()
        plt.xlabel('Seconds')
        plt.show()
        print()
# Out:
# count    37.000000
# mean      5.024866
# std       4.246217
# min       0.002199
# 25%       1.411203
# 50%       4.660863
# 75%       7.325566
# max      15.631531
# Name: SAGE_delay_discounting_raw_v6_baseline_dd_time_6_month___times_v0, dtype: float64
# count    37.000000
# mean      3.349532
# std       4.008249
# min       0.001047
# 25%       0.807888
# 50%       2.237985
# 75%       3.925374
# max      17.113201
# Name: SAGE_delay_discounting_raw_v6_baseline_dd_time_6_month___times_v1, dtype: float64
# count    37.000000
# mean      2.553946
# std       2.905424
# min       0.000830
# 25%       0.871056
# 50%       1.489683
# 75%       3.606917
# max      12.697113
# Name: SAGE_delay_discounting_raw_v6_baseline_dd_time_6_month___times_v2, dtype: float64
# count    37.000000
# mean      1.654453
# std       1.589365
# min       0.000605
# 25%       0.771053
# 50%       1.276381
# 75%       2.486131
# max       7.459464
# ...

# %% [markdown]
# ### Inquisit

# %%
elapsed_time = dmt['INQUISIT_delay_current___script.elapsedtime'] / 60000 #convert to minutes

# %%
elapsed_time.describe()
# Out:
# count    68.000000
# mean      7.091591
# std       4.762112
# min       2.994683
# 25%       5.113904
# 50%       6.214233
# 75%       7.551600
# max      40.218283
# Name: INQUISIT_delay_current___script.elapsedtime, dtype: float64

# %%
elapsed_time.plot.hist(title='Minutes')
