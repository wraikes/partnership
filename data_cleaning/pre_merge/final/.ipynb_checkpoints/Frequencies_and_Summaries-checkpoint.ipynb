# %% [markdown]
# #  Frequencies and Summary Statistics
#
# This file shows:
# - The summary statistics (count, mean, std, min, max, quantiles) for numeric data.
# - The frequency counts for categorical data, with at least one value greater than 1.
#
# To be viewed in HTML.

# %%
import os, numpy as np, pandas as pd
dmt = pd.read_csv('DMT_merged-DRAFT.csv')

# %%
for col in dmt.columns:
    if dmt[col].dtype == 'float':
        print(dmt[col].describe())
    elif dmt[col].dtype == 'object' and dmt[col].value_counts().max() > 1:
        counts = dmt[col].value_counts()
        perc = dmt[col].value_counts(normalize=True)
        print(pd.DataFrame({'counts':counts, 'percents':perc}))
        print('Name:', col)
    print()
# Out:
# count      74.000000
# mean      471.743243
# std       382.233346
# min         7.000000
# 25%       102.250000
# 50%       402.000000
# 75%       801.500000
# max      1283.000000
# Name: SAGE_gonogo_bl_stable_-_ROW_ID_x, dtype: float64
#
# count    74.000000
# mean     32.567568
# std      23.515125
# min       3.000000
# 25%      12.250000
# 50%      27.500000
# 75%      52.750000
# max      88.000000
# Name: SAGE_gonogo_bl_stable_-_ROW_VERSION_x, dtype: float64
#
#
#                         counts  percents
# version 1.0, build 16       28  0.252252
# version 1.2, build 18       25  0.225225
# version 1.0.2, build 1      15  0.135135
# version 1.1, build 17        5  0.045045
# version 1.0, build 15        1  0.009009
# Name: SAGE_gonogo_bl_stable_-_appVersion_x
#
#                             counts  percents
# iPhone 6; iOS/10.3.2             9  0.081081
# iPhone 7; iOS/10.3.2             8  0.072072
# iPhone 6S; iOS/10.3.2            5  0.045045
# iPhone 6+; iOS/10.3.2            4  0.036036
# iPhone 6S+; iOS/10.3.2           4  0.036036
# iPhone 7+; iOS/10.3.2            3  0.027027
# iPhone 6; iOS/10.3.3             3  0.027027
# iPhone 6; iOS/10.2.1             2  0.018018
# iPhone SE; iOS/10.3.2            2  0.018018
# iPhone 6S; iOS/10.3.3            2  0.018018
# iPhone 6; iOS/10.3.1             2  0.018018
# OnePlus ONEPLUS A3000            2  0.018018
# iPhone 7+; iOS/10.3.3            2  0.018018
# iPhone 6S+; iOS/10.3.1           1  0.009009
# iPhone 7; iOS/10.2.1             1  0.009009
# iPhone 7; iOS/10.3.1             1  0.009009
# BLU R1 HD                        1  0.009009
# LGE VS985 4G                     1  0.009009
# Samsung SAMSUNG-SM-G870A         1  0.009009
# OnePlus A0001                    1  0.009009
# HTC One M9                       1  0.009009
# iPhone 5S; iPhone OS/9.2.1       1  0.009009
# LGE LGLS775                      1  0.009009
# Samsung SM-G930T                 1  0.009009
# Samsung SAMSUNG-SM-G900A         1  0.009009
# iPhone 6S; iOS/10.3.1            1  0.009009
# Google Pixel                     1  0.009009
# Samsung SM-G900T                 1  0.009009
# iPhone 5S; iOS/10.3.3            1  0.009009
# iPhone 6S; iOS/10.2              1  0.009009
# iPhone 7+; iOS/10.2              1  0.009009
# Motorola Moto G (4)              1  0.009009
# iPhone 6S+; iOS/10.3.3           1  0.009009
# iPhone 5C; iOS/10.3.2            1  0.009009
# iPhone 6; iPhone OS/9.3.5        1  0.009009
# HTC6525LVW                       1  0.009009
# iPhone 5S; iOS/10.2.1            1  0.009009
# Samsung SM-G950U                 1  0.009009
# iPhone 6S; iOS/10.2.1            1  0.009009
# Name: SAGE_gonogo_bl_stable_-_phoneInfo_x
#
#            counts  percents
# 6/7/2017        7  0.063063
# 6/16/2017       5  0.045045
# 7/26/2017       5  0.045045
# 7/20/2017       4  0.036036
# 6/21/2017       3  0.027027
# 6/15/2017       3  0.027027
# 6/9/2017        2  0.018018
# 7/1/2017        2  0.018018
# 7/27/2017       2  0.018018
# 6/23/2017       2  0.018018
# 6/28/2017       2  0.018018
# 7/29/2017       2  0.018018
# 6/8/2017        2  0.018018
# 7/21/2017       2  0.018018
# 8/4/2017        2  0.018018
# 7/25/2017       2  0.018018
# 6/6/2017        2  0.018018
# 8/26/2017       2  0.018018
# 7/14/2017       2  0.018018
# 6/20/2017       2  0.018018
# 7/7/2017        2  0.018018
# 8/9/2017        2  0.018018
# 6/29/2017       2  0.018018
# 8/31/2017       1  0.009009
# 6/14/2017       1  0.009009
# 7/11/2017       1  0.009009
# 6/13/2017       1  0.009009
# 6/10/2017       1  0.009009
# 8/25/2017       1  0.009009
# 6/30/2017       1  0.009009
# 8/8/2017        1  0.009009
# 7/6/2017        1  0.009009
# 7/8/2017        1  0.009009
# 6/22/2017       1  0.009009
# 8/1/2017        1  0.009009
# 7/15/2017       1  0.009009
# Name: SAGE_gonogo_bl_stable_-_uploadDate_x
#
#
#
#
# count    7.400000e+01
# mean     1.499243e+12
# std      2.033583e+09
# min      1.496690e+12
# 25%      1.497485e+12
# 50%      1.498805e+12
# 75%      1.500975e+12
# max      1.504120e+12
# Name: SAGE_gonogo_bl_stable_-_createdOn_x, dtype: float64
#
# count     74
# mean    -400
# std        0
# min     -400
# 25%     -400
# 50%     -400
# 75%     -400
# max     -400
# Name: SAGE_gonogo_bl_stable_-_createdOnTimeZone_x, dtype: float64
#
#                            counts  percents
# ALL_QUALIFIED_RESEARCHERS      74  0.666667
# Name: SAGE_gonogo_bl_stable_-_userSharingScope_x
#
#
#           counts  percents
# baseline      74  0.666667
# Name: SAGE_gonogo_bl_stable_-_taskIdentifier_x
#
#
# count    7.400000e+01
# mean     1.499243e+12
# std      2.033583e+09
# min      1.496690e+12
# 25%      1.497485e+12
# 50%      1.498805e+12
# 75%      1.500975e+12
# max      1.504120e+12
# Name: SAGE_gonogo_bl_stable_-_startDate_x, dtype: float64
#
# count     74
# mean    -400
# std        0
# min     -400
# 25%     -400
# 50%     -400
# 75%     -400
# max     -400
# Name: SAGE_gonogo_bl_stable_-_startDate.timezone_x, dtype: float64
#
# count    7.400000e+01
# mean     1.499243e+12
# std      2.033583e+09
# min      1.496690e+12
# 25%      1.497485e+12
# 50%      1.498805e+12
# 75%      1.500975e+12
# max      1.504120e+12
# Name: SAGE_gonogo_bl_stable_-_endDate_x, dtype: float64
#
# count     74
# mean    -400
# std        0
# min     -400
# 25%     -400
# 50%     -400
# 75%     -400
# max     -400
# Name: SAGE_gonogo_bl_stable_-_endDate.timezone_x, dtype: float64
#
# count       70.000000
# mean      1063.285714
# std       8361.267373
# min         14.000000
# 25%         42.500000
# 50%         64.500000
# 75%         84.750000
# max      70019.000000
# Name: SAGE_gonogo_bl_stable_-_groupLabel_x, dtype: float64
#
#                                       counts  percents
# go_no_go_stable_stimulus_active_task      74  0.666667
# Name: SAGE_gonogo_bl_stable_-_variable_label_x
#
# count    74
# mean     75
# std       0
# min      75
# 25%      75
# 50%      75
# 75%      75
# max      75
# Name: SAGE_gonogo_bl_stable_-_number_of_trials_x, dtype: float64
#
# count    74.000000
# mean     36.297297
# std       7.149537
# min       7.000000
# 25%      35.000000
# 50%      37.500000
# 75%      41.000000
# max      45.000000
# Name: SAGE_gonogo_bl_stable_-_number_of_correct_responses_x, dtype: float64
#
# count    74.000000
# mean     12.432432
# std       2.472208
# min       7.000000
# 25%      11.000000
# 50%      13.000000
# 75%      14.000000
# max      19.000000
# Name: SAGE_gonogo_bl_stable_-_number_of_correct_responses_first_third_x, dtype: float64
#
# count    74.000000
# mean     11.621622
# std       3.451038
# min       0.000000
# 25%      10.000000
# 50%      12.000000
# 75%      14.000000
# max      17.000000
# Name: SAGE_gonogo_bl_stable_-_number_of_correct_responses_second_third_x, dtype: float64
#
# count    74.000000
# mean     12.243243
# std       3.475199
# min       0.000000
# 25%      11.000000
# 50%      13.000000
# 75%      15.000000
# max      17.000000
# Name: SAGE_gonogo_bl_stable_-_number_of_correct_responses_last_third_x, dtype: float64
#
# count    74.000000
# mean     36.635135
# std       4.208844
# min      26.000000
# 25%      34.000000
# 50%      36.500000
# 75%      39.000000
# max      46.000000
# Name: SAGE_gonogo_bl_stable_-_number_of_correct_nonresponses_x, dtype: float64
#
# count    74.000000
# mean     12.054054
# std       2.232339
# min       6.000000
# 25%      10.250000
# 50%      12.000000
# 75%      14.000000
# max      17.000000
# Name: SAGE_gonogo_bl_stable_-_number_of_correct_nonresponses_first_third_x, dtype: float64
#
# count    74.000000
# mean     12.554054
# std       2.410831
# min       7.000000
# 25%      11.000000
# 50%      13.000000
# 75%      14.000000
# max      18.000000
# Name: SAGE_gonogo_bl_stable_-_number_of_correct_nonresponses_second_third_x, dtype: float64
#
# count    74.000000
# mean     12.027027
# std       2.392757
# min       7.000000
# 25%      10.000000
# 50%      12.000000
# 75%      14.000000
# max      20.000000
# Name: SAGE_gonogo_bl_stable_-_number_of_correct_nonresponses_last_third_x, dtype: float64
#
# count    74.000000
# mean      0.432432
# std       0.795210
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       4.000000
# Name: SAGE_gonogo_bl_stable_-_number_of_incorrect_responses_x, dtype: float64
#
# count    74.000000
# mean      0.270270
# std       0.603581
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       3.000000
# Name: SAGE_gonogo_bl_stable_-_number_of_incorrect_responses_first_third_x, dtype: float64
#
# count    74.000000
# mean      0.081081
# std       0.320819
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       2.000000
# Name: SAGE_gonogo_bl_stable_-_number_of_incorrect_responses_second_third_x, dtype: float64
#
# count    74.000000
# mean      0.081081
# std       0.320819
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       2.000000
# Name: SAGE_gonogo_bl_stable_-_number_of_incorrect_responses_last_third_x, dtype: float64
#
# count    74.000000
# mean      1.635135
# std       5.650977
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max      33.000000
# Name: SAGE_gonogo_bl_stable_-_number_of_incorrect_nonresponses_x, dtype: float64
#
# count    74.000000
# mean      0.243243
# std       0.872892
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       6.000000
# Name: SAGE_gonogo_bl_stable_-_number_of_incorrect_nonresponses_first_third_x, dtype: float64
#
# count    74.000000
# mean      0.743243
# std       2.455415
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max      12.000000
# Name: SAGE_gonogo_bl_stable_-_number_of_incorrect_nonresponses_second_third_x, dtype: float64
#
# count    74.000000
# mean      0.648649
# std       2.608902
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max      15.000000
# Name: SAGE_gonogo_bl_stable_-_number_of_incorrect_nonresponses_last_third_x, dtype: float64
#
# count     74.000000
# mean     319.676529
# std      171.123705
# min        0.441156
# 25%      334.345575
# 50%      364.706263
# 75%      414.950973
# max      552.466871
# Name: SAGE_gonogo_bl_stable_-_response_time_mean_x, dtype: float64
#
# count     74.000000
# mean     325.505155
# std      174.875364
# min        0.439250
# 25%      337.968951
# 50%      372.895688
# 75%      417.815417
# max      586.579607
# Name: SAGE_gonogo_bl_stable_-_response_time_mean_first_third_x, dtype: float64
#
# count     74.000000
# mean     303.321720
# std      182.381993
# min        0.000000
# 25%      312.965911
# 50%      361.207620
# 75%      400.601445
# max      569.061692
# Name: SAGE_gonogo_bl_stable_-_response_time_mean_second_third_x, dtype: float64
#
# count     74.000000
# mean     297.018100
# std      177.579229
# min        0.000000
# 25%      293.481592
# 50%      361.626252
# 75%      403.541652
# max      555.659071
# Name: SAGE_gonogo_bl_stable_-_response_time_mean_last_third_x, dtype: float64
#
# count     74.000000
# mean     219.500294
# std      146.474211
# min        0.157000
# 25%      143.385261
# 50%      229.546040
# 75%      334.307477
# max      523.872018
# Name: SAGE_gonogo_bl_stable_-_response_time_range_x, dtype: float64
#
# count     74.000000
# mean     171.298611
# std      130.702577
# min        0.050000
# 25%      103.187546
# 50%      161.527485
# 75%      233.612999
# max      523.872018
# Name: SAGE_gonogo_bl_stable_-_response_time_range_first_third_x, dtype: float64
#
# count     74.000000
# mean     125.061969
# std       98.974363
# min        0.000000
# 25%       67.100257
# 50%      121.587962
# 75%      181.458518
# max      496.287942
# Name: SAGE_gonogo_bl_stable_-_response_time_range_second_third_x, dtype: float64
#
# count     74.000000
# mean     120.576455
# std       87.632860
# min        0.000000
# 25%       66.484958
# 50%      127.710432
# 75%      168.008462
# max      350.155950
# Name: SAGE_gonogo_bl_stable_-_response_time_range_last_third_x, dtype: float64
#
# count     74.000000
# mean      44.530861
# std       27.355772
# min        0.032695
# 25%       34.437397
# 50%       48.070453
# 75%       59.801593
# max      113.269719
# Name: SAGE_gonogo_bl_stable_-_response_time_std_dev_x, dtype: float64
#
# count     74.000000
# mean      46.769585
# std       34.710805
# min        0.017570
# 25%       29.242504
# 50%       44.038360
# 75%       61.395937
# max      145.891240
# Name: SAGE_gonogo_bl_stable_-_response_time_std_dev_first_third_x, dtype: float64
#
# count     74.000000
# mean      34.431440
# std       25.523938
# min        0.000000
# 25%       20.720325
# 50%       36.876812
# 75%       49.909632
# max      114.038389
# Name: SAGE_gonogo_bl_stable_-_response_time_std_dev_second_third_x, dtype: float64
#
# count    74.000000
# mean     33.810587
# std      24.007109
# min       0.000000
# 25%      21.618142
# 50%      35.840096
# 75%      46.106106
# max      98.062078
# Name: SAGE_gonogo_bl_stable_-_response_time_std_dev_last_third_x, dtype: float64
#
# count     74.000000
# mean     159.941974
# std      254.858678
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%      276.730269
# max      750.000000
# Name: SAGE_gonogo_bl_stable_-_response_time_mean_after_one_incorrect_x, dtype: float64
#
# count     74.000000
# mean      74.632175
# std      177.609427
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max      750.000000
# Name: SAGE_gonogo_bl_stable_-_response_time_mean_after_one_incorrect_first_third_x, dtype: float64
#
# count     74.000000
# mean     100.827743
# std      243.768339
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max      750.000000
# Name: SAGE_gonogo_bl_stable_-_response_time_mean_after_one_incorrect_second_third_x, dtype: float64
# count     74.000000
# mean      78.011365
# std      211.263414
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max      750.000000
# Name: SAGE_gonogo_bl_stable_-_response_time_mean_after_one_incorrect_last_third_x, dtype: float64
#
# count     74.000000
# mean     485.330592
# std      286.274715
# min        0.000000
# 25%      341.418773
# 50%      559.381753
# 75%      750.000000
# max      750.000000
# Name: SAGE_gonogo_bl_stable_-_response_time_mean_after_ten_correct_x, dtype: float64
#
# count     74.000000
# mean     482.343485
# std      291.303202
# min        0.000000
# 25%      339.156270
# 50%      508.684486
# 75%      750.000000
# max      750.000000
# Name: SAGE_gonogo_bl_stable_-_response_time_mean_after_ten_correct_first_third_x, dtype: float64
#
# count     74.000000
# mean      72.624542
# std      204.807147
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max      750.000000
# Name: SAGE_gonogo_bl_stable_-_response_time_mean_after_ten_correct_second_third_x, dtype: float64
#
# count     74.000000
# mean      74.715189
# std      213.113842
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max      750.000000
# Name: SAGE_gonogo_bl_stable_-_response_time_mean_after_ten_correct_last_third_x, dtype: float64
#
# count     74.000000
# mean     319.876312
# std      171.057867
# min        0.444545
# 25%      336.991179
# 50%      365.301737
# 75%      415.252916
# max      552.466871
# Name: SAGE_gonogo_bl_stable_-_response_time_mean_correct_x, dtype: float64
#
# count     74.000000
# mean     325.987244
# std      174.875091
# min        0.439250
# 25%      342.582581
# 50%      372.895688
# 75%      417.421873
# max      586.579607
# Name: SAGE_gonogo_bl_stable_-_response_time_mean_correct_first_third_x, dtype: float64
#
# count     74.000000
# mean     303.155949
# std      182.374520
# min        0.000000
# 25%      312.965911
# 50%      359.188537
# 75%      400.601445
# max      569.061692
# Name: SAGE_gonogo_bl_stable_-_response_time_mean_correct_second_third_x, dtype: float64
#
# count     74.000000
# mean     297.465245
# std      177.636892
# min        0.000000
# 25%      305.211093
# 50%      361.626252
# 75%      403.541652
# max      555.659071
# Name: SAGE_gonogo_bl_stable_-_response_time_mean_correct_last_third_x, dtype: float64
#
# count     74.000000
# mean      87.361052
# std      161.532808
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%      127.401250
# max      696.328998
# Name: SAGE_gonogo_bl_stable_-_response_time_mean_incorrect_x, dtype: float64
#
# count     74.000000
# mean      62.703141
# std      146.826816
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max      696.328998
# Name: SAGE_gonogo_bl_stable_-_response_time_mean_incorrect_first_third_x, dtype: float64
#
# count     74.000000
# mean      19.750608
# std       87.688287
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max      535.321981
# Name: SAGE_gonogo_bl_stable_-_response_time_mean_incorrect_second_third_x, dtype: float64
#
# count     74.000000
# mean      17.200554
# std       65.334379
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max      293.105006
# Name: SAGE_gonogo_bl_stable_-_response_time_mean_incorrect_last_third_x, dtype: float64
#
# count     0
# mean    NaN
# std     NaN
# min     NaN
# 25%     NaN
# 50%     NaN
# 75%     NaN
# max     NaN
# Name: SAGE_gonogo_bl_stable_-_researcher_code_x, dtype: float64
#
# count      73.000000
# mean      480.821918
# std       377.281590
# min        10.000000
# 25%       109.000000
# 50%       421.000000
# 75%       799.000000
# max      1281.000000
# Name: SAGE_gonogo_21_variable_-_ROW_ID_x, dtype: float64
#
# count    73.000000
# mean     33.191781
# std      23.274126
# min       3.000000
# 25%      13.000000
# 50%      28.000000
# 75%      53.000000
# max      88.000000
# Name: SAGE_gonogo_21_variable_-_ROW_VERSION_x, dtype: float64
#
#
#                         counts  percents
# version 1.0, build 16       26  0.234234
# version 1.2, build 18       25  0.225225
# version 1.0.2, build 1      16  0.144144
# version 1.1, build 17        5  0.045045
# version 1.0, build 15        1  0.009009
# Name: SAGE_gonogo_21_variable_-_appVersion_x
#
#                             counts  percents
# iPhone 7; iOS/10.3.2             8  0.072072
# iPhone 6; iOS/10.3.2             8  0.072072
# iPhone 6S; iOS/10.3.2            5  0.045045
# iPhone 6+; iOS/10.3.2            4  0.036036
# iPhone 6S+; iOS/10.3.2           4  0.036036
# iPhone 7+; iOS/10.3.2            3  0.027027
# iPhone 6; iOS/10.3.3             3  0.027027
# iPhone 7+; iOS/10.3.3            2  0.018018
# OnePlus ONEPLUS A3000            2  0.018018
# iPhone 6; iOS/10.2.1             2  0.018018
# iPhone SE; iOS/10.3.2            2  0.018018
# iPhone 6; iOS/10.3.1             2  0.018018
# iPhone 6S; iOS/10.3.3            2  0.018018
# Samsung SAMSUNG-SM-G870A         1  0.009009
# iPhone 7; iOS/10.2.1             1  0.009009
# iPhone 7; iOS/10.3.1             1  0.009009
# iPhone 6S+; iOS/10.3.1           1  0.009009
# iPhone 5S; iPhone OS/9.2.1       1  0.009009
# OnePlus A0001                    1  0.009009
# HTC One M9                       1  0.009009
# BLU R1 HD                        1  0.009009
# Samsung SM-G930T                 1  0.009009
# Google Pixel                     1  0.009009
# Samsung SAMSUNG-SM-G900A         1  0.009009
# LGE LGLS775                      1  0.009009
# LGE LG-K330                      1  0.009009
# iPhone 6S; iOS/10.3.1            1  0.009009
# Samsung SM-G900T                 1  0.009009
# iPhone 5S; iOS/10.3.3            1  0.009009
# iPhone 6S; iOS/10.2              1  0.009009
# iPhone 7+; iOS/10.2              1  0.009009
# Motorola Moto G (4)              1  0.009009
# iPhone 6S+; iOS/10.3.3           1  0.009009
# iPhone 5C; iOS/10.3.2            1  0.009009
# LGE VS985 4G                     1  0.009009
# HTC6525LVW                       1  0.009009
# iPhone 5S; iOS/10.2.1            1  0.009009
# Samsung SM-G950U                 1  0.009009
# iPhone 6S; iOS/10.2.1            1  0.009009
# Name: SAGE_gonogo_21_variable_-_phoneInfo_x
#
#            counts  percents
# 6/7/2017        6  0.054054
# 7/26/2017       5  0.045045
# 7/20/2017       4  0.036036
# 6/16/2017       4  0.036036
# 6/9/2017        3  0.027027
# 6/15/2017       3  0.027027
# 6/21/2017       3  0.027027
# 6/23/2017       2  0.018018
# 7/29/2017       2  0.018018
# 6/28/2017       2  0.018018
# 7/21/2017       2  0.018018
# 8/4/2017        2  0.018018
# 7/25/2017       2  0.018018
# 7/1/2017        2  0.018018
# 6/20/2017       2  0.018018
# 6/29/2017       2  0.018018
# 7/14/2017       2  0.018018
# 7/27/2017       2  0.018018
# 6/30/2017       2  0.018018
# 8/26/2017       2  0.018018
# 8/9/2017        2  0.018018
# 7/7/2017        2  0.018018
# 6/8/2017        2  0.018018
# 6/10/2017       1  0.009009
# 7/11/2017       1  0.009009
# 7/15/2017       1  0.009009
# 7/6/2017        1  0.009009
# 7/8/2017        1  0.009009
# 6/22/2017       1  0.009009
# 8/1/2017        1  0.009009
# 8/31/2017       1  0.009009
# 8/8/2017        1  0.009009
# 8/25/2017       1  0.009009
# 6/13/2017       1  0.009009
# 6/14/2017       1  0.009009
# 6/6/2017        1  0.009009
# Name: SAGE_gonogo_21_variable_-_uploadDate_x
#
#
#
# count    7.300000e+01
# mean     1.499295e+12
# std      2.015689e+09
# min      1.496690e+12
# 25%      1.497490e+12
# 50%      1.498830e+12
# 75%      1.500990e+12
# max      1.504120e+12
# Name: SAGE_gonogo_21_variable_-_createdOn_x, dtype: float64
#
# count     73
# mean    -400
# std        0
# min     -400
# 25%     -400
# 50%     -400
# 75%     -400
# max     -400
# Name: SAGE_gonogo_21_variable_-_createdOnTimeZone_x, dtype: float64
#
#                            counts  percents
# ALL_QUALIFIED_RESEARCHERS      73  0.657658
# Name: SAGE_gonogo_21_variable_-_userSharingScope_x
#
#
#           counts  percents
# baseline      73  0.657658
# Name: SAGE_gonogo_21_variable_-_taskIdentifier_x
#
#
# count    7.300000e+01
# mean     1.499295e+12
# std      2.015689e+09
# min      1.496690e+12
# 25%      1.497490e+12
# 50%      1.498830e+12
# 75%      1.500990e+12
# max      1.504120e+12
# Name: SAGE_gonogo_21_variable_-_startDate_x, dtype: float64
#
# count     73
# mean    -400
# std        0
# min     -400
# 25%     -400
# 50%     -400
# 75%     -400
# max     -400
# Name: SAGE_gonogo_21_variable_-_startDate.timezone_x, dtype: float64
#
# count    7.300000e+01
# mean     1.499295e+12
# std      2.015689e+09
# min      1.496690e+12
# 25%      1.497490e+12
# 50%      1.498830e+12
# 75%      1.500990e+12
# max      1.504120e+12
# Name: SAGE_gonogo_21_variable_-_endDate_x, dtype: float64
#
# count     73
# mean    -400
# std        0
# min     -400
# 25%     -400
# 50%     -400
# 75%     -400
# max     -400
# Name: SAGE_gonogo_21_variable_-_endDate.timezone_x, dtype: float64
#
# count       70.000000
# mean      1063.471429
# std       8361.244392
# min         14.000000
# 25%         45.000000
# 50%         64.500000
# 75%         84.750000
# max      70019.000000
# Name: SAGE_gonogo_21_variable_-_groupLabel_x, dtype: float64
#
#                                         counts  percents
# go_no_go_variable_stimulus_active_task      73  0.657658
# Name: SAGE_gonogo_21_variable_-_variable_label_x
#
# count    73
# mean     75
# std       0
# min      75
# 25%      75
# 50%      75
# 75%      75
# max      75
# Name: SAGE_gonogo_21_variable_-_number_of_trials_x, dtype: float64
#
# count    73.000000
# mean     36.534247
# std       5.270679
# min      11.000000
# 25%      34.000000
# 50%      36.000000
# 75%      40.000000
# max      45.000000
# Name: SAGE_gonogo_21_variable_-_number_of_correct_responses_x, dtype: float64
#
# count    73.000000
# mean     12.082192
# std       2.390685
# min       7.000000
# 25%      10.000000
# 50%      12.000000
# 75%      14.000000
# max      18.000000
# Name: SAGE_gonogo_21_variable_-_number_of_correct_responses_first_third_x, dtype: float64
#
# count    73.000000
# mean     12.602740
# std       2.998795
# min       0.000000
# 25%      11.000000
# 50%      13.000000
# 75%      14.000000
# max      21.000000
# Name: SAGE_gonogo_21_variable_-_number_of_correct_responses_second_third_x, dtype: float64
#
# count    73.000000
# mean     11.849315
# std       3.035307
# min       0.000000
# 25%      10.000000
# 50%      12.000000
# 75%      14.000000
# max      18.000000
# Name: SAGE_gonogo_21_variable_-_number_of_correct_responses_last_third_x, dtype: float64
#
# count    73.000000
# mean     37.205479
# std       4.462681
# min      28.000000
# 25%      34.000000
# 50%      38.000000
# 75%      40.000000
# max      46.000000
# Name: SAGE_gonogo_21_variable_-_number_of_correct_nonresponses_x, dtype: float64
#
# count    73.000000
# mean     12.534247
# std       2.409946
# min       7.000000
# 25%      11.000000
# 50%      13.000000
# 75%      14.000000
# max      18.000000
# Name: SAGE_gonogo_21_variable_-_number_of_correct_nonresponses_first_third_x, dtype: float64
#
# count    73.000000
# mean     11.972603
# std       2.748599
# min       4.000000
# 25%      10.000000
# 50%      12.000000
# 75%      14.000000
# max      17.000000
# Name: SAGE_gonogo_21_variable_-_number_of_correct_nonresponses_second_third_x, dtype: float64
#
# count    73.000000
# mean     12.698630
# std       2.721748
# min       6.000000
# 25%      11.000000
# 50%      13.000000
# 75%      14.000000
# max      19.000000
# Name: SAGE_gonogo_21_variable_-_number_of_correct_nonresponses_last_third_x, dtype: float64
#
# count    73.000000
# mean      0.410959
# std       0.796444
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       3.000000
# Name: SAGE_gonogo_21_variable_-_number_of_incorrect_responses_x, dtype: float64
#
# count    73.000000
# mean      0.136986
# std       0.384241
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       2.000000
# Name: SAGE_gonogo_21_variable_-_number_of_incorrect_responses_first_third_x, dtype: float64
#
# count    73.000000
# mean      0.136986
# std       0.346212
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000
# Name: SAGE_gonogo_21_variable_-_number_of_incorrect_responses_second_third_x, dtype: float64
#
# count    73.000000
# mean      0.136986
# std       0.418830
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       2.000000
# Name: SAGE_gonogo_21_variable_-_number_of_incorrect_responses_last_third_x, dtype: float64
#
# count    73.000000
# mean      0.849315
# std       3.277326
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max      27.000000
# Name: SAGE_gonogo_21_variable_-_number_of_incorrect_nonresponses_x, dtype: float64
#
# count    73.000000
# mean      0.246575
# std       0.572053
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       3.000000
# Name: SAGE_gonogo_21_variable_-_number_of_incorrect_nonresponses_first_third_x, dtype: float64
#
# count    73.000000
# mean      0.287671
# std       1.687202
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max      14.000000
# Name: SAGE_gonogo_21_variable_-_number_of_incorrect_nonresponses_second_third_x, dtype: float64
#
# count    73.000000
# mean      0.315068
# std       1.489563
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max      12.000000
# Name: SAGE_gonogo_21_variable_-_number_of_incorrect_nonresponses_last_third_x, dtype: float64
# count     73.000000
# mean     316.714744
# std      177.743311
# min        0.439489
# 25%      330.360685
# 50%      373.043629
# 75%      418.667023
# max      598.074149
# Name: SAGE_gonogo_21_variable_-_response_time_mean_x, dtype: float64
#
# count     73.000000
# mean     324.625298
# std      182.405994
# min        0.425333
# 25%      325.717211
# 50%      375.216287
# 75%      441.621508
# max      608.314365
# Name: SAGE_gonogo_21_variable_-_response_time_mean_first_third_x, dtype: float64
#
# count     73.000000
# mean     307.641889
# std      179.946470
# min        0.000000
# 25%      313.257178
# 50%      368.398873
# 75%      419.554745
# max      615.631436
# Name: SAGE_gonogo_21_variable_-_response_time_mean_second_third_x, dtype: float64
#
# count     73.000000
# mean     307.116794
# std      179.761016
# min        0.000000
# 25%      313.937442
# 50%      357.332855
# 75%      417.992890
# max      559.804824
# Name: SAGE_gonogo_21_variable_-_response_time_mean_last_third_x, dtype: float64
#
# count     73.000000
# mean     207.729878
# std      144.950663
# min        0.117000
# 25%      149.989009
# 50%      220.912993
# 75%      267.382979
# max      616.137981
# Name: SAGE_gonogo_21_variable_-_response_time_range_x, dtype: float64
#
# count     73.000000
# mean     151.541845
# std      108.693861
# min        0.100000
# 25%       75.900972
# 50%      166.400969
# 75%      206.429005
# max      443.938017
# Name: SAGE_gonogo_21_variable_-_response_time_range_first_third_x, dtype: float64
#
# count     73.000000
# mean     126.911575
# std      100.260004
# min        0.000000
# 25%       71.561992
# 50%      128.982961
# 75%      170.096993
# max      473.019004
# Name: SAGE_gonogo_21_variable_-_response_time_range_second_third_x, dtype: float64
#
# count     73.000000
# mean     139.592712
# std      107.683715
# min        0.000000
# 25%       66.150010
# 50%      135.456026
# 75%      219.480991
# max      380.119026
# Name: SAGE_gonogo_21_variable_-_response_time_range_last_third_x, dtype: float64
#
# count     73.000000
# mean      43.262544
# std       27.475955
# min        0.027701
# 25%       33.989968
# 50%       46.347176
# 75%       59.713229
# max      100.969420
# Name: SAGE_gonogo_21_variable_-_response_time_std_dev_x, dtype: float64
#
# count     73.000000
# mean      42.323987
# std       29.402788
# min        0.027285
# 25%       23.558253
# 50%       42.966581
# 75%       56.697267
# max      129.714142
# Name: SAGE_gonogo_21_variable_-_response_time_std_dev_first_third_x, dtype: float64
#
# count     73.000000
# mean      35.430414
# std       27.026707
# min        0.000000
# 25%       20.072350
# 50%       36.033822
# 75%       49.291563
# max      122.235780
# Name: SAGE_gonogo_21_variable_-_response_time_std_dev_second_third_x, dtype: float64
#
# count     73.000000
# mean      38.774107
# std       28.501103
# min        0.000000
# 25%       19.793358
# 50%       38.197350
# 75%       57.101819
# max      103.768448
# Name: SAGE_gonogo_21_variable_-_response_time_std_dev_last_third_x, dtype: float64
#
# count     73.000000
# mean     144.752550
# std      254.959665
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%      253.872653
# max      750.000000
# Name: SAGE_gonogo_21_variable_-_response_time_mean_after_one_incorrect_x, dtype: float64
#
# count     73.000000
# mean      89.604288
# std      220.554632
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max      750.000000
# Name: SAGE_gonogo_21_variable_-_response_time_mean_after_one_incorrect_first_third_x, dtype: float64
#
# count     73.000000
# mean      43.196430
# std      131.179854
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max      750.000000
# Name: SAGE_gonogo_21_variable_-_response_time_mean_after_one_incorrect_second_third_x, dtype: float64
#
# count     73.000000
# mean      71.512534
# std      197.910326
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max      750.000000
# Name: SAGE_gonogo_21_variable_-_response_time_mean_after_one_incorrect_last_third_x, dtype: float64
#
# count     73.000000
# mean     469.474506
# std      289.676608
# min        0.000000
# 25%      328.355521
# 50%      530.429006
# 75%      750.000000
# max      750.000000
# Name: SAGE_gonogo_21_variable_-_response_time_mean_after_ten_correct_x, dtype: float64
#
# count     73.000000
# mean     480.508070
# std      296.448285
# min        0.000000
# 25%      334.377050
# 50%      537.056506
# 75%      750.000000
# max      750.000000
# Name: SAGE_gonogo_21_variable_-_response_time_mean_after_ten_correct_first_third_x, dtype: float64
#
# count     73.000000
# mean      58.500164
# std      171.643168
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max      750.000000
# Name: SAGE_gonogo_21_variable_-_response_time_mean_after_ten_correct_second_third_x, dtype: float64
#
# count     73.000000
# mean      36.129685
# std      142.464953
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max      750.000000
# Name: SAGE_gonogo_21_variable_-_response_time_mean_after_ten_correct_last_third_x, dtype: float64
#
# count     73.000000
# mean     317.579549
# std      178.050439
# min        0.448089
# 25%      332.666759
# 50%      373.043629
# 75%      419.760432
# max      598.074149
# Name: SAGE_gonogo_21_variable_-_response_time_mean_correct_x, dtype: float64
#
# count     73.000000
# mean     325.240077
# std      182.718280
# min        0.425333
# 25%      330.141999
# 50%      374.629319
# 75%      441.621508
# max      608.314365
# Name: SAGE_gonogo_21_variable_-_response_time_mean_correct_first_third_x, dtype: float64
#
# count     73.000000
# mean     308.464159
# std      180.251610
# min        0.000000
# 25%      313.257178
# 50%      376.033221
# 75%      419.554745
# max      615.631436
# Name: SAGE_gonogo_21_variable_-_response_time_mean_correct_second_third_x, dtype: float64
#
# count     73.000000
# mean     308.302808
# std      180.107395
# min        0.000000
# 25%      313.937442
# 50%      358.100382
# 75%      418.996672
# max      559.804824
# Name: SAGE_gonogo_21_variable_-_response_time_mean_correct_last_third_x, dtype: float64
#
# count     73.000000
# mean      55.514862
# std      119.756359
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.320000
# max      424.174011
# Name: SAGE_gonogo_21_variable_-_response_time_mean_incorrect_x, dtype: float64
#
# count     73.000000
# mean      27.979082
# std       95.478241
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max      424.174011
# Name: SAGE_gonogo_21_variable_-_response_time_mean_incorrect_first_third_x, dtype: float64
#
# count     73.000000
# mean      29.525752
# std       88.314998
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max      379.752994
# Name: SAGE_gonogo_21_variable_-_response_time_mean_incorrect_second_third_x, dtype: float64
#
# count     73.000000
# mean      20.146041
# std       69.853912
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max      313.515008
# Name: SAGE_gonogo_21_variable_-_response_time_mean_incorrect_last_third_x, dtype: float64
#
# count     0
# mean    NaN
# std     NaN
# min     NaN
# 25%     NaN
# 50%     NaN
# 75%     NaN
# max     NaN
# Name: SAGE_gonogo_21_variable_-_researcher_code_x, dtype: float64
#
# count      60.000000
# mean      779.333333
# std       323.829295
# min        88.000000
# 25%       525.250000
# 50%       738.000000
# 75%      1124.250000
# max      1271.000000
# Name: SAGE_gonogo_bl_stable_-_ROW_ID_y, dtype: float64
#
# count    60.000000
# mean     50.883333
# std      21.343908
# min      11.000000
# 25%      32.750000
# 50%      47.000000
# 75%      73.250000
# max      87.000000
# Name: SAGE_gonogo_bl_stable_-_ROW_VERSION_y, dtype: float64
#
#
#                         counts  percents
# version 1.2, build 18       28  0.252252
# version 1.0, build 16       16  0.144144
# version 1.0.2, build 1      11  0.099099
# version 1.1, build 17        4  0.036036
# version 1.0, build 15        1  0.009009
# Name: SAGE_gonogo_bl_stable_-_appVersion_y
#
#                            counts  percents
# iPhone 6; iOS/10.3.2            6  0.054054
# iPhone 6; iOS/10.3.3            4  0.036036
# iPhone 6+; iOS/10.3.2           3  0.027027
# iPhone 7; iOS/10.3.2            3  0.027027
# iPhone 7+; iOS/10.3.3           3  0.027027
# iPhone 7; iOS/10.3.3            3  0.027027
# iPhone 6S; iOS/10.3.3           3  0.027027
# iPhone 6S; iOS/10.3.2           3  0.027027
# iPhone 6S+; iOS/10.3.3          2  0.018018
# iPhone 6; iOS/10.2.1            2  0.018018
# iPhone 7+; iOS/10.3.2           2  0.018018
# iPhone 6S+; iOS/10.3.2          2  0.018018
# OnePlus A0001                   1  0.009009
# iPhone 6S+; iOS/10.3.1          1  0.009009
# LGE LGLS775                     1  0.009009
# OnePlus ONEPLUS A3000           1  0.009009
# iPhone 7; iOS/10.3.1            1  0.009009
# Samsung SAMSUNG-SM-G870A        1  0.009009
# BLU R1 HD                       1  0.009009
# Samsung SM-G930T                1  0.009009
# iPhone SE; iOS/10.3.3           1  0.009009
# LGE VS985 4G                    1  0.009009
# Google Pixel                    1  0.009009
# Samsung SM-G900T                1  0.009009
# iPhone 5S; iOS/10.3.3           1  0.009009
# iPhone 6S; iOS/10.2             1  0.009009
# iPhone 7+; iOS/10.2             1  0.009009
# iPhone 6; iOS/10.3.1            1  0.009009
# iPhone 6+; iOS/10.3.3           1  0.009009
# iPhone 5C; iOS/10.3.2           1  0.009009
# iPhone 6; iPhone OS/9.3.5       1  0.009009
# iPhone SE; iOS/10.3.2           1  0.009009
# HTC6525LVW                      1  0.009009
# iPhone 5S; iOS/10.2.1           1  0.009009
# Samsung SM-G950U                1  0.009009
# iPhone 6S; iOS/10.2.1           1  0.009009
# Name: SAGE_gonogo_bl_stable_-_phoneInfo_y
#
#            counts  percents
# 6/29/2017       4  0.036036
# 8/16/2017       4  0.036036
# 7/4/2017        3  0.027027
# 7/20/2017       3  0.027027
# 7/12/2017       3  0.027027
# 7/7/2017        3  0.027027
# 8/17/2017       3  0.027027
# 6/28/2017       3  0.027027
# 8/25/2017       2  0.018018
# 8/10/2017       2  0.018018
# 7/6/2017        2  0.018018
# 7/28/2017       2  0.018018
# 6/27/2017       2  0.018018
# 8/30/2017       2  0.018018
# 6/30/2017       1  0.009009
# 8/22/2017       1  0.009009
# 7/22/2017       1  0.009009
# 7/13/2017       1  0.009009
# 6/14/2017       1  0.009009
# 8/11/2017       1  0.009009
# 8/12/2017       1  0.009009
# 7/9/2017        1  0.009009
# 7/11/2017       1  0.009009
# 8/15/2017       1  0.009009
# 8/23/2017       1  0.009009
# 7/5/2017        1  0.009009
# 8/8/2017        1  0.009009
# 7/8/2017        1  0.009009
# 7/30/2017       1  0.009009
# 8/1/2017        1  0.009009
# 8/4/2017        1  0.009009
# 7/27/2017       1  0.009009
# 8/19/2017       1  0.009009
# 7/25/2017       1  0.009009
# 7/19/2017       1  0.009009
# 8/29/2017       1  0.009009
# Name: SAGE_gonogo_bl_stable_-_uploadDate_y
#
#
#
# count    6.000000e+01
# mean     1.500833e+12
# std      1.846792e+09
# min      1.497410e+12
# 25%      1.499232e+12
# 50%      1.500485e+12
# 75%      1.502762e+12
# max      1.504060e+12
# Name: SAGE_gonogo_bl_stable_-_createdOn_y, dtype: float64
#
# count     60.000000
# mean    -403.333333
# std       18.102033
# min     -500.000000
# 25%     -400.000000
# 50%     -400.000000
# 75%     -400.000000
# max     -400.000000
# Name: SAGE_gonogo_bl_stable_-_createdOnTimeZone_y, dtype: float64
#
#                            counts  percents
# ALL_QUALIFIED_RESEARCHERS      60  0.540541
# Name: SAGE_gonogo_bl_stable_-_userSharingScope_y
#
#
#                    counts  percents
# 21-day-assessment      60  0.540541
# Name: SAGE_gonogo_bl_stable_-_taskIdentifier_y
#
#
# count    6.000000e+01
# mean     1.500832e+12
# std      1.847018e+09
# min      1.497410e+12
# 25%      1.499232e+12
# 50%      1.500485e+12
# 75%      1.502762e+12
# max      1.504060e+12
# Name: SAGE_gonogo_bl_stable_-_startDate_y, dtype: float64
#
# count     60.000000
# mean    -403.333333
# std       18.102033
# min     -500.000000
# 25%     -400.000000
# 50%     -400.000000
# 75%     -400.000000
# max     -400.000000
# Name: SAGE_gonogo_bl_stable_-_startDate.timezone_y, dtype: float64
#
# count    6.000000e+01
# mean     1.500833e+12
# std      1.846792e+09
# min      1.497410e+12
# 25%      1.499232e+12
# 50%      1.500485e+12
# 75%      1.502762e+12
# max      1.504060e+12
# Name: SAGE_gonogo_bl_stable_-_endDate_y, dtype: float64
#
# count     60.000000
# mean    -403.333333
# std       18.102033
# min     -500.000000
# 25%     -400.000000
# 50%     -400.000000
# 75%     -400.000000
# max     -400.000000
# Name: SAGE_gonogo_bl_stable_-_endDate.timezone_y, dtype: float64
#
#
#                                       counts  percents
# go_no_go_stable_stimulus_active_task      60  0.540541
# Name: SAGE_gonogo_bl_stable_-_variable_label_y
#
# count    60
# mean     75
# std       0
# min      75
# 25%      75
# 50%      75
# 75%      75
# max      75
# Name: SAGE_gonogo_bl_stable_-_number_of_trials_y, dtype: float64
# count    60.000000
# mean     36.150000
# std       7.743395
# min       0.000000
# 25%      34.000000
# 50%      37.000000
# 75%      40.000000
# max      45.000000
# Name: SAGE_gonogo_bl_stable_-_number_of_correct_responses_y, dtype: float64
#
# count    60.000000
# mean     11.750000
# std       3.587289
# min       0.000000
# 25%      10.000000
# 50%      12.000000
# 75%      14.000000
# max      19.000000
# Name: SAGE_gonogo_bl_stable_-_number_of_correct_responses_first_third_y, dtype: float64
#
# count    60.000000
# mean     12.450000
# std       3.538768
# min       0.000000
# 25%      11.000000
# 50%      13.000000
# 75%      14.250000
# max      18.000000
# Name: SAGE_gonogo_bl_stable_-_number_of_correct_responses_second_third_y, dtype: float64
#
# count    60.000000
# mean     11.950000
# std       3.441644
# min       0.000000
# 25%      10.000000
# 50%      12.000000
# 75%      14.000000
# max      18.000000
# Name: SAGE_gonogo_bl_stable_-_number_of_correct_responses_last_third_y, dtype: float64
#
# count    60.000000
# mean     36.450000
# std       4.081479
# min      25.000000
# 25%      34.000000
# 50%      37.000000
# 75%      39.000000
# max      45.000000
# Name: SAGE_gonogo_bl_stable_-_number_of_correct_nonresponses_y, dtype: float64
#
# count    60.000000
# mean     12.566667
# std       3.049683
# min       6.000000
# 25%      11.000000
# 50%      13.000000
# 75%      14.000000
# max      20.000000
# Name: SAGE_gonogo_bl_stable_-_number_of_correct_nonresponses_first_third_y, dtype: float64
#
# count    60.000000
# mean     11.866667
# std       2.696304
# min       7.000000
# 25%      10.000000
# 50%      11.000000
# 75%      14.000000
# max      18.000000
# Name: SAGE_gonogo_bl_stable_-_number_of_correct_nonresponses_second_third_y, dtype: float64
#
# count    60.000000
# mean     12.016667
# std       2.960140
# min       3.000000
# 25%      10.000000
# 50%      12.000000
# 75%      14.000000
# max      17.000000
# Name: SAGE_gonogo_bl_stable_-_number_of_correct_nonresponses_last_third_y, dtype: float64
#
# count    60.000000
# mean      0.550000
# std       1.015557
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       5.000000
# Name: SAGE_gonogo_bl_stable_-_number_of_incorrect_responses_y, dtype: float64
#
# count    60.000000
# mean      0.133333
# std       0.430477
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       2.000000
# Name: SAGE_gonogo_bl_stable_-_number_of_incorrect_responses_first_third_y, dtype: float64
#
# count    60.000000
# mean      0.116667
# std       0.323732
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000
# Name: SAGE_gonogo_bl_stable_-_number_of_incorrect_responses_second_third_y, dtype: float64
#
# count    60.000000
# mean      0.300000
# std       0.808849
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       5.000000
# Name: SAGE_gonogo_bl_stable_-_number_of_incorrect_responses_last_third_y, dtype: float64
#
# count    60.000000
# mean      1.850000
# std       6.584072
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max      39.000000
# Name: SAGE_gonogo_bl_stable_-_number_of_incorrect_nonresponses_y, dtype: float64
#
# count    60.00000
# mean      0.55000
# std       2.37519
# min       0.00000
# 25%       0.00000
# 50%       0.00000
# 75%       0.00000
# max      16.00000
# Name: SAGE_gonogo_bl_stable_-_number_of_incorrect_nonresponses_first_third_y, dtype: float64
#
# count    60.000000
# mean      0.566667
# std       2.181328
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max      14.000000
# Name: SAGE_gonogo_bl_stable_-_number_of_incorrect_nonresponses_second_third_y, dtype: float64
#
# count    60.000000
# mean      0.733333
# std       2.335189
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max      15.000000
# Name: SAGE_gonogo_bl_stable_-_number_of_incorrect_nonresponses_last_third_y, dtype: float64
#
# count     60.000000
# mean     315.206528
# std      167.074710
# min        0.000000
# 25%      322.961749
# 50%      368.209580
# 75%      412.678425
# max      577.623606
# Name: SAGE_gonogo_bl_stable_-_response_time_mean_y, dtype: float64
#
# count     60.000000
# mean     315.139490
# std      167.182310
# min        0.000000
# 25%      319.609725
# 50%      372.766420
# 75%      404.585293
# max      586.140499
# Name: SAGE_gonogo_bl_stable_-_response_time_mean_first_third_y, dtype: float64
#
# count     60.000000
# mean     310.560429
# std      173.382424
# min        0.000000
# 25%      321.180214
# 50%      367.335932
# 75%      416.378117
# max      578.498911
# Name: SAGE_gonogo_bl_stable_-_response_time_mean_second_third_y, dtype: float64
#
# count     60.000000
# mean     309.055042
# std      174.823562
# min        0.000000
# 25%      303.959037
# 50%      361.299971
# 75%      412.642406
# max      590.876818
# Name: SAGE_gonogo_bl_stable_-_response_time_mean_last_third_y, dtype: float64
#
# count     60.000000
# mean     244.471918
# std      183.696972
# min        0.000000
# 25%      129.232720
# 50%      234.010011
# 75%      328.087524
# max      737.975061
# Name: SAGE_gonogo_bl_stable_-_response_time_range_y, dtype: float64
#
# count     60.000000
# mean     157.328585
# std      143.574230
# min        0.000000
# 25%       66.256478
# 50%      131.368041
# 75%      214.663014
# max      684.595048
# Name: SAGE_gonogo_bl_stable_-_response_time_range_first_third_y, dtype: float64
#
# count     60.000000
# mean     158.330565
# std      131.131362
# min        0.000000
# 25%       86.845025
# 50%      139.899462
# 75%      227.060735
# max      679.636002
# Name: SAGE_gonogo_bl_stable_-_response_time_range_second_third_y, dtype: float64
#
# count     60.000000
# mean     171.698264
# std      132.360492
# min        0.000000
# 25%       89.128256
# 50%      150.604010
# 75%      251.847535
# max      533.576071
# Name: SAGE_gonogo_bl_stable_-_response_time_range_last_third_y, dtype: float64
#
# count     60.000000
# mean      49.045896
# std       34.605695
# min        0.000000
# 25%       30.281928
# 50%       50.940651
# 75%       68.225705
# max      155.783392
# Name: SAGE_gonogo_bl_stable_-_response_time_std_dev_y, dtype: float64
#
# count     60.000000
# mean      43.448721
# std       36.866727
# min        0.000000
# 25%       20.462434
# 50%       40.002490
# 75%       59.193679
# max      157.059299
# Name: SAGE_gonogo_bl_stable_-_response_time_std_dev_first_third_y, dtype: float64
#
# count     60.000000
# mean      43.291856
# std       33.776375
# min        0.000000
# 25%       24.557085
# 50%       41.762456
# 75%       57.910684
# max      146.606793
# Name: SAGE_gonogo_bl_stable_-_response_time_std_dev_second_third_y, dtype: float64
#
# count     60.000000
# mean      45.953302
# std       34.384089
# min        0.000000
# 25%       25.756678
# 50%       42.756028
# 75%       60.052082
# max      118.744965
# Name: SAGE_gonogo_bl_stable_-_response_time_std_dev_last_third_y, dtype: float64
#
# count     60.000000
# mean     184.612272
# std      266.729489
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%      283.229515
# max      750.000000
# Name: SAGE_gonogo_bl_stable_-_response_time_mean_after_one_incorrect_y, dtype: float64
#
# count     60.000000
# mean      67.816908
# std      192.931844
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max      750.000000
# Name: SAGE_gonogo_bl_stable_-_response_time_mean_after_one_incorrect_first_third_y, dtype: float64
#
# count     60.000000
# mean      98.979067
# std      228.018677
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max      750.000000
# Name: SAGE_gonogo_bl_stable_-_response_time_mean_after_one_incorrect_second_third_y, dtype: float64
#
# count     60.000000
# mean     138.243182
# std      256.878888
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%      211.670868
# max      750.000000
# Name: SAGE_gonogo_bl_stable_-_response_time_mean_after_one_incorrect_last_third_y, dtype: float64
#
# count     60.000000
# mean     433.341826
# std      275.366854
# min        0.000000
# 25%      316.423476
# 50%      420.726001
# 75%      750.000000
# max      759.885013
# Name: SAGE_gonogo_bl_stable_-_response_time_mean_after_ten_correct_y, dtype: float64
#
# count     60.000000
# mean     429.438049
# std      281.489193
# min        0.000000
# 25%      308.063999
# 50%      385.005981
# 75%      750.000000
# max      759.885013
# Name: SAGE_gonogo_bl_stable_-_response_time_mean_after_ten_correct_first_third_y, dtype: float64
#
# count     60.000000
# mean      47.331333
# std      152.242641
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max      750.000000
# Name: SAGE_gonogo_bl_stable_-_response_time_mean_after_ten_correct_second_third_y, dtype: float64
#
# count     60.000000
# mean     136.788583
# std      273.306824
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max      750.000000
# Name: SAGE_gonogo_bl_stable_-_response_time_mean_after_ten_correct_last_third_y, dtype: float64
#
# count     60.000000
# mean     316.038023
# std      167.315617
# min        0.000000
# 25%      327.463526
# 50%      369.303454
# 75%      412.678425
# max      577.623606
# Name: SAGE_gonogo_bl_stable_-_response_time_mean_correct_y, dtype: float64
#
# count     60.000000
# mean     315.371313
# std      167.152555
# min        0.000000
# 25%      323.944114
# 50%      372.766420
# 75%      404.585293
# max      586.140499
# Name: SAGE_gonogo_bl_stable_-_response_time_mean_correct_first_third_y, dtype: float64
#
# count     60.000000
# mean     311.082981
# std      173.614108
# min        0.000000
# 25%      321.180214
# ...
# 75%       9.500000
# max      10.000000
# Name: INQUISIT_delay_original_-_values.t2_ip, dtype: float64
#
# count    34
# mean      1
# std       0
# min       1
# 25%       1
# 50%       1
# 75%       1
# max       1
# Name: INQUISIT_delay_original_-_values.t3_ip_found, dtype: float64
#
# count    34.000000
# mean      6.500000
# std       3.005046
# min       0.500000
# 25%       5.000000
# 50%       6.500000
# 75%       9.000000
# max      10.000000
# Name: INQUISIT_delay_original_-_values.t3_ip, dtype: float64
#
# count    34
# mean      1
# std       0
# min       1
# 25%       1
# 50%       1
# 75%       1
# max       1
# Name: INQUISIT_delay_original_-_values.t4_ip_found, dtype: float64
#
# count    34.000000
# mean      3.941176
# std       3.173672
# min       0.500000
# 25%       1.000000
# 50%       3.500000
# 75%       6.375000
# max       9.500000
# Name: INQUISIT_delay_original_-_values.t4_ip, dtype: float64
#
# count    34
# mean      1
# std       0
# min       1
# 25%       1
# 50%       1
# 75%       1
# max       1
# Name: INQUISIT_delay_original_-_values.t5_ip_found, dtype: float64
#
# count    34.000000
# mean      3.205882
# std       2.926156
# min       0.500000
# 25%       0.625000
# 50%       1.750000
# 75%       5.500000
# max       9.500000
# Name: INQUISIT_delay_original_-_values.t5_ip, dtype: float64
#
# count    34
# mean      1
# std       0
# min       1
# 25%       1
# 50%       1
# 75%       1
# max       1
# Name: INQUISIT_delay_original_-_values.p1_ip_found, dtype: float64
#
# count    34.000000
# mean      9.426471
# std       0.478830
# min       7.000000
# 25%       9.500000
# 50%       9.500000
# 75%       9.500000
# max      10.000000
# Name: INQUISIT_delay_original_-_values.p1_ip, dtype: float64
#
# count    34
# mean      1
# std       0
# min       1
# 25%       1
# 50%       1
# 75%       1
# max       1
# Name: INQUISIT_delay_original_-_values.p2_ip_found, dtype: float64
#
# count    34.000000
# mean      7.661765
# std       2.241890
# min       0.500000
# 25%       7.500000
# 50%       8.500000
# 75%       9.000000
# max       9.500000
# Name: INQUISIT_delay_original_-_values.p2_ip, dtype: float64
#
# count    34
# mean      1
# std       0
# min       1
# 25%       1
# 50%       1
# 75%       1
# max       1
# Name: INQUISIT_delay_original_-_values.p3_ip_found, dtype: float64
#
# count    34.000000
# mean      6.073529
# std       2.332681
# min       0.500000
# 25%       5.500000
# 50%       6.750000
# 75%       7.375000
# max       9.500000
# Name: INQUISIT_delay_original_-_values.p3_ip, dtype: float64
#
# count    34.000000
# mean      0.941176
# std       0.238833
# min       0.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       1.000000
# Name: INQUISIT_delay_original_-_values.p4_ip_found, dtype: float64
#
# count    34.000000
# mean      3.823529
# std       2.194630
# min       0.000000
# 25%       1.750000
# 50%       4.500000
# 75%       5.375000
# max       8.000000
# Name: INQUISIT_delay_original_-_values.p4_ip, dtype: float64
#
# count    34.000000
# mean      0.970588
# std       0.171499
# min       0.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       1.000000
# Name: INQUISIT_delay_original_-_values.p5_ip_found, dtype: float64
#
# count    34.000000
# mean      2.308824
# std       1.590763
# min       0.000000
# 25%       1.000000
# 50%       2.000000
# 75%       3.000000
# max       7.000000
# Name: INQUISIT_delay_original_-_values.p5_ip, dtype: float64
#
#                                                     counts  percents
# Would you rather have  (a) $9 now or (b) $10 in...       2  0.018018
# Would you rather have  (a) $8.5 now or (b) $10 ...       2  0.018018
# Would you rather have  (a) $8 now or (b) $10 in...       2  0.018018
# Would you rather have  (a) $0.5 now or (b) $10 ...       1  0.009009
# Would you rather have  (a) $9.5 now or (b) $10 ...       1  0.009009
# Would you rather have  (a) $6.5 now or (b) $10 ...       1  0.009009
# Would you rather have  (a) $9.5 for sure or (b)...       1  0.009009
# Would you rather have  (a) $6 for sure or (b) $...       1  0.009009
# Would you rather have  (a) $8.5 now or (b) $10 ...       1  0.009009
# Would you rather have  (a) $10 now or (b) $10 i...       1  0.009009
# Would you rather have  (a) $8.5 for sure or (b)...       1  0.009009
# Would you rather have  (a) $3.5 for sure or (b)...       1  0.009009
# Would you rather have  (a) $4 for sure or (b) $...       1  0.009009
# Would you rather have  (a) $4 now or (b) $10 in...       1  0.009009
# Would you rather have  (a) $2.5 for sure or (b)...       1  0.009009
# Would you rather have  (a) $10 now or (b) $10 i...       1  0.009009
# Would you rather have  (a) $4.5 now or (b) $10 ...       1  0.009009
# Would you rather have  (a) $7.5 now or (b) $10 ...       1  0.009009
# Would you rather have  (a) $4.5 for sure or (b)...       1  0.009009
# Would you rather have  (a) $8 for sure or (b) $...       1  0.009009
# Would you rather have  (a) $3.5 now or (b) $10 ...       1  0.009009
# Would you rather have  (a) $6.5 for sure or (b)...       1  0.009009
# Would you rather have  (a) $0 for sure or (b) $...       1  0.009009
# Would you rather have  (a) $7.5 for sure or (b)...       1  0.009009
# Would you rather have  (a) $5 for sure or (b) $...       1  0.009009
# Would you rather have  (a) $6.5 now or (b) $10 ...       1  0.009009
# Would you rather have  (a) $6 for sure or (b) $...       1  0.009009
# Would you rather have  (a) $2.5 now or (b) $10 ...       1  0.009009
# Would you rather have  (a) $3.5 for sure or (b)...       1  0.009009
# Would you rather have  (a) $5 for sure or (b) $...       1  0.009009
# Would you rather have  (a) $8 now or (b) $10 in...       1  0.009009
# Name: INQUISIT_delay_original_-_text.subjectquestion.currentitem
#
#    counts  percents
# B      20  0.180180
# A      14  0.126126
# Name: INQUISIT_delay_original_-_text.subjectanswer.currentitem
#
# count    12
# mean      1
# std       0
# min       1
# 25%       1
# 50%       1
# 75%       1
# max       1
# Name: INQUISIT_delay_v2_-_script.groupid, dtype: float64
#
# count       12.000000
# mean     62333.666667
# std        383.366270
# min      61917.000000
# 25%      62017.000000
# 50%      62167.000000
# 75%      62717.000000
# max      62817.000000
# Name: INQUISIT_delay_v2_-_script.startdate, dtype: float64
#
#
# count         12.000000
# mean      726747.166667
# std       227668.047277
# min       455061.000000
# 25%       584803.000000
# 50%       696101.500000
# 75%       812807.000000
# max      1254973.000000
# Name: INQUISIT_delay_v2_-_script.elapsedtime, dtype: float64
#
#      counts  percents
# win      12  0.108108
# Name: INQUISIT_delay_v2_-_computer.platform
#
# count    12
# mean      1
# std       0
# min       1
# 25%       1
# 50%       1
# 75%       1
# max       1
# Name: INQUISIT_delay_v2_-_values.completed, dtype: float64
#
# count    12.000000
# mean      4.083333
# std       1.975225
# min       1.000000
# 25%       3.000000
# 50%       3.500000
# 75%       5.250000
# max       8.000000
# Name: INQUISIT_delay_v2_-_expressions.nips, dtype: float64
#
# count    12.000000
# mean      0.333333
# std       0.492366
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000
# Name: INQUISIT_delay_v2_-_values.t1_ip_found, dtype: float64
#
# count    12.000000
# mean      3.125000
# std       4.617777
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       9.125000
# max       9.500000
# Name: INQUISIT_delay_v2_-_values.t1_ip, dtype: float64
#
# count    12.000000
# mean      0.750000
# std       0.452267
# min       0.000000
# 25%       0.750000
# 50%       1.000000
# 75%       1.000000
# max       1.000000
# Name: INQUISIT_delay_v2_-_values.t2_ip_found, dtype: float64
#
# count    12.000000
# mean      6.916667
# std       4.198665
# min       0.000000
# 25%       6.000000
# 50%       9.000000
# 75%       9.500000
# max      10.000000
# Name: INQUISIT_delay_v2_-_values.t2_ip, dtype: float64
#
# count    12.000000
# mean      0.416667
# std       0.514929
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000
# Name: INQUISIT_delay_v2_-_values.t3_ip_found, dtype: float64
# count    12.000000
# mean      2.625000
# std       3.908761
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       5.875000
# max       9.500000
# Name: INQUISIT_delay_v2_-_values.t3_ip, dtype: float64
#
# count    12.000000
# mean      0.333333
# std       0.492366
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000
# Name: INQUISIT_delay_v2_-_values.t4_ip_found, dtype: float64
#
# count    12.000000
# mean      0.625000
# std       1.707271
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.500000
# max       6.000000
# Name: INQUISIT_delay_v2_-_values.t4_ip, dtype: float64
#
# count    12.000000
# mean      0.500000
# std       0.522233
# min       0.000000
# 25%       0.000000
# 50%       0.500000
# 75%       1.000000
# max       1.000000
# Name: INQUISIT_delay_v2_-_values.t5_ip_found, dtype: float64
#
# count    12.000000
# mean      0.750000
# std       1.196586
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.875000
# max       3.000000
# Name: INQUISIT_delay_v2_-_values.t5_ip, dtype: float64
#
# count    12.000000
# mean      0.750000
# std       0.452267
# min       0.000000
# 25%       0.750000
# 50%       1.000000
# 75%       1.000000
# max       1.000000
# Name: INQUISIT_delay_v2_-_values.p1_ip_found, dtype: float64
#
# count    12.000000
# mean      7.208333
# std       4.350853
# min       0.000000
# 25%       7.125000
# 50%       9.500000
# 75%       9.500000
# max      10.000000
# Name: INQUISIT_delay_v2_-_values.p1_ip, dtype: float64
#
# count    12.000000
# mean      0.250000
# std       0.452267
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.250000
# max       1.000000
# Name: INQUISIT_delay_v2_-_values.p2_ip_found, dtype: float64
#
# count    12.000000
# mean      2.291667
# std       4.147608
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       2.250000
# max       9.500000
# Name: INQUISIT_delay_v2_-_values.p2_ip, dtype: float64
#
# count    12.000000
# mean      0.250000
# std       0.452267
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.250000
# max       1.000000
# Name: INQUISIT_delay_v2_-_values.p3_ip_found, dtype: float64
#
# count    12.000000
# mean      1.708333
# std       3.875672
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.125000
# max      10.000000
# Name: INQUISIT_delay_v2_-_values.p3_ip, dtype: float64
#
# count    12.000000
# mean      0.250000
# std       0.452267
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.250000
# max       1.000000
# Name: INQUISIT_delay_v2_-_values.p4_ip_found, dtype: float64
#
# count    12.000000
# mean      0.916667
# std       2.054190
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.125000
# max       6.000000
# Name: INQUISIT_delay_v2_-_values.p4_ip, dtype: float64
#
# count    12.000000
# mean      0.250000
# std       0.452267
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.250000
# max       1.000000
# Name: INQUISIT_delay_v2_-_values.p5_ip_found, dtype: float64
#
# count    12.000
# mean      0.250
# std       0.500
# min       0.000
# 25%       0.000
# 50%       0.000
# 75%       0.125
# max       1.500
# Name: INQUISIT_delay_v2_-_values.p5_ip, dtype: float64
#
#
#    counts  percents
# B       7  0.063063
# A       5  0.045045
# Name: INQUISIT_delay_v2_-_text.subjectanswer.currentitem
#
# count      102.000000
# mean     68960.137255
# std      12367.920095
# min      41317.000000
# 25%      61317.000000
# 50%      66767.000000
# 75%      73042.000000
# max      90817.000000
# Name: INQUISIT_gonogo_-_script.startdate, dtype: float64
#
#
#          counts  percents
# 0:00:00      27  0.243243
# 816247        1  0.009009
# 756713        1  0.009009
# 1139193       1  0.009009
# 778596        1  0.009009
# 792186        1  0.009009
# 805714        1  0.009009
# 947407        1  0.009009
# 794960        1  0.009009
# 809147        1  0.009009
# 784228        1  0.009009
# 780347        1  0.009009
# 845808        1  0.009009
# 805240        1  0.009009
# 820687        1  0.009009
# 771223        1  0.009009
# 823799        1  0.009009
# 1115669       1  0.009009
# 1041013       1  0.009009
# 791194        1  0.009009
# 1073828       1  0.009009
# 773221        1  0.009009
# 800822        1  0.009009
# 801197        1  0.009009
# 788036        1  0.009009
# 1036013       1  0.009009
# 767410        1  0.009009
# 802414        1  0.009009
# 802994        1  0.009009
# 805913        1  0.009009
# ...         ...       ...
# 787746        1  0.009009
# 775572        1  0.009009
# 933009        1  0.009009
# 801099        1  0.009009
# 899556        1  0.009009
# 790016        1  0.009009
# 816736        1  0.009009
# 796058        1  0.009009
# 801595        1  0.009009
# 866536        1  0.009009
# 770823        1  0.009009
# 797088        1  0.009009
# 788120        1  0.009009
# 789969        1  0.009009
# 1336573       1  0.009009
# 780216        1  0.009009
# 836893        1  0.009009
# 812094        1  0.009009
# 766490        1  0.009009
# 1025960       1  0.009009
# 780076        1  0.009009
# 846500        1  0.009009
# 797486        1  0.009009
# 825230        1  0.009009
# 772648        1  0.009009
# 781029        1  0.009009
# 780820        1  0.009009
# 794424        1  0.009009
# 804733        1  0.009009
# 775482        1  0.009009
#
# [76 rows x 2 columns]
# Name: INQUISIT_gonogo_-_script.elapsedtime
#
#      counts  percents
# win     102  0.918919
# Name: INQUISIT_gonogo_-_computer.platform
#
# count    102
# mean       1
# std        0
# min        1
# 25%        1
# 50%        1
# 75%        1
# max        1
# Name: INQUISIT_gonogo_-_values.completed, dtype: float64
#
# count    102.000000
# mean       0.040667
# std        0.156903
# min        0.000000
# 25%        0.000000
# 50%        0.004000
# 75%        0.008000
# max        0.992000
# Name: INQUISIT_gonogo_-_expressions.errorrate, dtype: float64
#
# count    102.000000
# mean       0.054039
# std        0.214891
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.008000
# max        1.000000
# Name: INQUISIT_gonogo_-_expressions.errorrate_gotarget, dtype: float64
#
# count    102.000000
# mean       0.027294
# std        0.133602
# min        0.000000
# 25%        0.000000
# 50%        0.008000
# 75%        0.008000
# max        0.992000
# Name: INQUISIT_gonogo_-_expressions.errorrate_Nogotarget, dtype: float64
#
# count    102.000000
# mean       0.049569
# std        0.189415
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.008000
# max        1.000000
# Name: INQUISIT_gonogo_-_expressions.error_verticalcue, dtype: float64
#
# count    102.000000
# mean       0.031765
# std        0.136562
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.014000
# max        0.984000
# Name: INQUISIT_gonogo_-_expressions.error_horizontalcue, dtype: float64
#
# count    102.000000
# mean       0.053725
# std        0.215305
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.010000
# max        1.000000
# Name: INQUISIT_gonogo_-_expressions.omissionerror_v, dtype: float64
#
# count    102.000000
# mean       0.032941
# std        0.137002
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
# Name: INQUISIT_gonogo_-_expressions.inhibitionerror_v, dtype: float64
#
# count    102.000000
# mean       0.055294
# std        0.213823
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
# Name: INQUISIT_gonogo_-_expressions.omissionerror_h, dtype: float64
#
# count    102.000000
# mean       0.025882
# std        0.133523
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.010000
# max        0.990000
# Name: INQUISIT_gonogo_-_expressions.inhibitionerror_h, dtype: float64
#
# count     99.000000
# mean     348.635648
# std       44.001340
# min      230.000000
# 25%      309.868000
# 50%      341.800000
# 75%      377.676000
# max      458.952000
# Name: INQUISIT_gonogo_-_expressions.meanrt, dtype: float64
#
# count     98.000000
# mean     348.946914
# std       42.126497
# min      283.230000
# 25%      312.777500
# 50%      340.548535
# 75%      377.065000
# max      460.540000
# Name: INQUISIT_gonogo_-_expressions.meanrt_verticalcue_gotarget, dtype: float64
#
# count     99.000000
# mean     352.472576
# std       47.990327
# min      224.000000
# 25%      313.720000
# 50%      349.880000
# 75%      385.860000
# max      461.560000
# Name: INQUISIT_gonogo_-_expressions.meanrt_horizontalcue_gotarget, dtype: float64
