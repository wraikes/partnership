# %% [markdown]
# ## Inquisit Data Merge

# %%
import os, pandas as pd, numpy as np
from functools import reduce
pd.set_option('display.max_columns', 100)

#NOTE TO SELF: redo the relative paths.
#inquisit = '/home/wraikes/Dropbox/partnership/DMTdata_9_8_17/inquisit/'
inquisit = r'C:\Users\williamr.PDFK\Dropbox\partnership\dmt_temp'

# %%
os.chdir(inquisit)  

bart = pd.read_csv('BART_Merged_9.8.17.csv')
delay1 = pd.read_csv('DelayDiscounting_Current_Merged_9.8.17.csv')
delay2 = pd.read_csv('DelayDiscounting_Original_Merged_9.8.17.csv')
delay3 = pd.read_csv('DelayDiscounting_v2_Merged_9.8.17.csv')
gonogo = pd.read_csv('GoNoGo_Merged_9.8.17.csv')

dfs = [bart, delay1, delay2, delay3, gonogo]

# %%
def column_relabel(df, append_1, col_name):
    
    '''A function to relabel the columns
    with the df name appended to each 
    column name.'''
    
    new_cols = []
    for col in df.columns:
        if col != col_name:
            new_col = append_1 + col
            new_cols.append(new_col)
        else:
            new_cols.append(col)
    
    return new_cols

def new_dfs(_dfs, _names, _id):
    
    new_df = []
    
    for df, name in zip(_dfs, _names):
        df.columns = column_relabel(df, name, _id)
        new_df.append(df)

    return new_df

# %%
#Relabel the columns

names = [
    'INQUISIT_bart___', 
    'INQUISIT_delay_current___', 
    'INQUISIT_delay_original___',
    'INQUISIT_delay_v2___',
    'INQUISIT_gonogo___'
        ]

clean_dfs = new_dfs(dfs, names, 'script.subjectid')

# %%
#Merge data
inquisit_merge = reduce(lambda left, right: pd.merge(left, right, how = 'outer',
                                                     on='script.subjectid'), 
                                                     clean_dfs)

# %% [markdown]
# ### Test Data Accuacy

# %%
#Check to see if script.subjectid (InternalID) is in Inquisit data.
cols = [x.columns for x in dfs]
all(['script.subjectid' in list for list in cols])
# Out:
# True

# %%
#Check for duplicate internalId's
len(inquisit_merge['script.subjectid']) == len(inquisit_merge['script.subjectid'].unique())
# Out:
# True

# %%
inquisit_merge.head()
# Out:
#    INQUISIT_bart___script.startdate INQUISIT_bart___script.starttime  \
# 0                               NaN                              NaN
# 1                           90717.0                         11:02:11
# 2                           41317.0                         15:58:00
# 3                           41817.0                         18:07:45
# 4                           90617.0                         15:17:54
#
#    script.subjectid INQUISIT_bart___script.elapsedtime  \
# 0             70001                                NaN
# 1             70002                             373328
# 2             70003                            0:00:00
# 3             70004                            0:00:00
# 4             70005                             270418
#
#   INQUISIT_bart___computer.platform  INQUISIT_bart___values.completed  \
# 0                               NaN                               NaN
# 1                               win                               1.0
# 2                               win                               1.0
# 3                               win                               1.0
# 4                               win                               1.0
#
#    INQUISIT_bart___values.ballooncount  \
# 0                                  NaN
# 1                                 30.0
# 2                                 30.0
# 3                                 30.0
# 4                                 30.0
#
#    INQUISIT_bart___values.ballooncount_10  \
# 0                                     NaN
# 1                                    10.0
# 2                                    10.0
# 3                                    10.0
# 4                                    10.0
#
#    INQUISIT_bart___values.ballooncount_20  \
# 0                                     NaN
# 1                                    10.0
# 2                                    10.0
# 3                                    10.0
# 4                                    10.0
#
#    INQUISIT_bart___values.ballooncount_30  \
# 0                                     NaN
# 1                                    10.0
# 2                                    10.0
# 3                                    10.0
# 4                                    10.0
#
#    INQUISIT_bart___values.totalpumpcount  \
# 0                                    NaN
# 1                                 1137.0
# 2                                 1042.0
# 3                                  664.0
# 4                                  891.0
#
#    INQUISIT_bart___values.totalpumpcount_10  \
# 0                                       NaN
# 1                                     381.0
# 2                                     367.0
# 3                                      84.0
# 4                                     202.0
#
#    INQUISIT_bart___values.totalpumpcount_20  \
# 0                                       NaN
# 1                                     320.0
# 2                                     356.0
# 3                                     261.0
# 4                                     356.0
#
#    INQUISIT_bart___values.totalpumpcount_30  \
# 0                                       NaN
# 1                                     436.0
# 2                                     319.0
# 3                                     319.0
# 4                                     333.0
#
#    INQUISIT_bart___values.averagepumpcount  \
# 0                                      NaN
# 1                                37.900000
# 2                                34.733333
# 3                                22.133333
# 4                                29.700000
#
#    INQUISIT_bart___values.averagepumpcount_10  \
# 0                                         NaN
# 1                                        38.1
# 2                                        36.7
# 3                                         8.4
# 4                                        20.2
#
#    INQUISIT_bart___values.averagepumpcount_20  \
# 0                                         NaN
# 1                                        32.0
# 2                                        35.6
# 3                                        26.1
# 4                                        35.6
#
#    INQUISIT_bart___values.averagepumpcount_30  \
# 0                                         NaN
# 1                                        43.6
# 2                                        31.9
# 3                                        31.9
# 4                                        33.3
#
#    INQUISIT_bart___values.total_explosions  \
# 0                                      NaN
# 1                                      8.0
# 2                                      9.0
# 3                                      6.0
# 4                                     10.0
#
#    INQUISIT_bart___values.total_explosions_10  \
# 0                                         NaN
# 1                                         3.0
# 2                                         1.0
# 3                                         0.0
# 4                                         3.0
#
#    INQUISIT_bart___values.total_explosions_20  \
# 0                                         NaN
# 1                                         3.0
# 2                                         6.0
# 3                                         2.0
# 4                                         2.0
#
#    INQUISIT_bart___values.total_explosions_30  \
# 0                                         NaN
# 1                                         2.0
# 2                                         2.0
# 3                                         4.0
# 4                                         5.0
#
#    INQUISIT_bart___values.nonexplodedballoons  \
# 0                                         NaN
# 1                                        22.0
# 2                                        21.0
# 3                                        24.0
# 4                                        20.0
#
#    INQUISIT_bart___values.nonexplodedballoons_10  \
# 0                                            NaN
# 1                                            7.0
# 2                                            9.0
# 3                                           10.0
# 4                                            7.0
#
#    INQUISIT_bart___values.nonexplodedballoons_20  \
# 0                                            NaN
# 1                                            7.0
# 2                                            4.0
# 3                                            8.0
# 4                                            8.0
#
#    INQUISIT_bart___values.nonexplodedballoons_30  \
# 0                                            NaN
# 1                                            8.0
# 2                                            8.0
# 3                                            6.0
# 4                                            5.0
#
#    INQUISIT_bart___values.adjustedtotalpumpcount  \
# 0                                            NaN
# 1                                          870.0
# 2                                          815.0
# 3                                          582.0
# 4                                          733.0
#
#    INQUISIT_bart___values.adjustedtotalpumpcount_10  \
# 0                                               NaN
# 1                                             260.0
# 2                                             361.0
# 3                                              84.0
# 4                                             158.0
#
#    INQUISIT_bart___values.adjustedtotalpumpcount_20  \
# 0                                               NaN
# 1                                             220.0
# 2                                             187.0
# 3                                             248.0
# 4                                             340.0
#
#    INQUISIT_bart___values.adjustedtotalpumpcount_30  \
# 0                                               NaN
# 1                                             390.0
# 2                                             267.0
# 3                                             250.0
# 4                                             235.0
#
#    INQUISIT_bart___values.adjustedaveragepumpcount  \
# 0                                              NaN
# 1                                        39.545455
# 2                                        38.809524
# 3                                        24.250000
# 4                                        36.650000
#
#    INQUISIT_bart___values.adjustedaveragepumpcount_10  \
# 0                                                NaN
# 1                                          37.142857
# 2                                          40.111111
# 3                                           8.400000
# 4                                          22.571429
#
#    INQUISIT_bart___values.adjustedaveragepumpcount_20  \
# 0                                                NaN
# 1                                          31.428571
# 2                                          46.750000
# 3                                          31.000000
# 4                                          42.500000
#
#    INQUISIT_bart___values.adjustedaveragepumpcount_30  \
# 0                                                NaN
# 1                                          48.750000
# 2                                          33.375000
# 3                                          41.666667
# 4                                          47.000000
#
#   INQUISIT_delay_current___script.groupid  \
# 0                                     NaN
# 1                                       1
# 2                                     NaN
# 3                                     NaN
# 4                                       1
#
#    INQUISIT_delay_current___script.startdate  \
# 0                                        NaN
# 1                                    90717.0
# 2                                        NaN
# 3                                        NaN
# 4                                    90617.0
#
#   INQUISIT_delay_current___script.starttime  \
# 0                                       NaN
# 1                                  11:21:59
# 2                                       NaN
# 3                                       NaN
# 4                                  15:37:00
#
#    INQUISIT_delay_current___script.elapsedtime  \
# 0                                          NaN
# 1                                     262392.0
# 2                                          NaN
# 3                                          NaN
# 4                                     322203.0
#
#   INQUISIT_delay_current___computer.platform  \
# 0                                        NaN
# 1                                        win
# 2                                        NaN
# 3                                        NaN
# 4                                        win
#
#    INQUISIT_delay_current___values.completed  \
# 0                                        NaN
# 1                                        1.0
# 2                                        NaN
# 3                                        NaN
# 4                                        1.0
#
#    INQUISIT_delay_current___expressions.nips  \
# 0                                        NaN
# 1                                        3.0
# 2                                        NaN
# 3                                        NaN
# 4                                        0.0
#
#    INQUISIT_delay_current___values.t3_ip_found  \
# 0                                          NaN
# 1                                          1.0
# 2                                          NaN
# 3                                          NaN
# 4                                          0.0
#
#    INQUISIT_delay_current___values.t3_ip  \
# 0                                    NaN
# 1                                    1.0
# 2                                    NaN
# 3                                    NaN
# 4                                    0.0
#
#    INQUISIT_delay_current___values.t4_ip_found  \
# 0                                          NaN
# 1                                          1.0
# 2                                          NaN
# 3                                          NaN
# 4                                          0.0
#
#    INQUISIT_delay_current___values.t4_ip  \
# 0                                    NaN
# 1                                    0.5
# 2                                    NaN
# 3                                    NaN
# 4                                    0.0
#
#    INQUISIT_delay_current___values.t5_ip_found  \
# 0                                          NaN
# 1                                          1.0
# 2                                          NaN
# 3                                          NaN
# 4                                          0.0
#
#    INQUISIT_delay_current___values.t5_ip  \
# 0                                    NaN
# 1                                    0.5
# 2                                    NaN
# 3                                    NaN
# 4                                    0.0
#
#    INQUISIT_delay_current___values.p4_ip_found  \
# 0                                          NaN
# 1                                          0.0
# 2                                          NaN
# 3                                          NaN
# 4                                          0.0
#
#    INQUISIT_delay_current___values.p4_ip  \
# 0                                    NaN
# 1                                    0.0
# 2                                    NaN
# 3                                    NaN
# 4                                    0.0
#
#   INQUISIT_delay_current___text.subjectquestion.currentitem  \
# 0                                                NaN
# 1  Would you rather have  (a) $0 now or (b) $10 i...
# 2                                                NaN
# 3                                                NaN
# 4  Would you rather have  (a) $8 for sure or (b) ...
#
#                               ...                               \
# 0                             ...
# 1                             ...
# 2                             ...
# 3                             ...
# 4                             ...
#
#   INQUISIT_delay_original___values.p5_ip_found  \
# 0                                          NaN
# 1                                          NaN
# 2                                          1.0
# 3                                          1.0
# 4                                          NaN
#
#   INQUISIT_delay_original___values.p5_ip  \
# 0                                    NaN
# 1                                    NaN
# 2                                    5.5
# 3                                    4.5
# 4                                    NaN
#
#    INQUISIT_delay_original___text.subjectquestion.currentitem  \
# 0                                                NaN
# 1                                                NaN
# 2  Would you rather have  (a) $9.5 for sure or (b...
# 3  Would you rather have  (a) $5 for sure or (b) ...
# 4                                                NaN
#
#   INQUISIT_delay_original___text.subjectanswer.currentitem  \
# 0                                                NaN
# 1                                                NaN
# 2                                                  B
# 3                                                  B
# 4                                                NaN
#
#    INQUISIT_delay_v2___script.groupid INQUISIT_delay_v2___script.startdate  \
# 0                                 NaN                                  NaN
# 1                                 NaN                                  NaN
# 2                                 NaN                                  NaN
# 3                                 NaN                                  NaN
# 4                                 NaN                                  NaN
#
#    INQUISIT_delay_v2___script.starttime  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#    INQUISIT_delay_v2___script.elapsedtime  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    INQUISIT_delay_v2___computer.platform  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    INQUISIT_delay_v2___values.completed  INQUISIT_delay_v2___expressions.nips  \
# 0                                   NaN                                   NaN
# 1                                   NaN                                   NaN
# 2                                   NaN                                   NaN
# 3                                   NaN                                   NaN
# 4                                   NaN                                   NaN
#
#    INQUISIT_delay_v2___values.t1_ip_found  INQUISIT_delay_v2___values.t1_ip  \
# 0                                     NaN                               NaN
# 1                                     NaN                               NaN
# 2                                     NaN                               NaN
# 3                                     NaN                               NaN
# 4                                     NaN                               NaN
#
#    INQUISIT_delay_v2___values.t2_ip_found  INQUISIT_delay_v2___values.t2_ip  \
# 0                                     NaN                               NaN
# 1                                     NaN                               NaN
# 2                                     NaN                               NaN
# 3                                     NaN                               NaN
# 4                                     NaN                               NaN
#
#    INQUISIT_delay_v2___values.t3_ip_found  INQUISIT_delay_v2___values.t3_ip  \
# 0                                     NaN                               NaN
# 1                                     NaN                               NaN
# 2                                     NaN                               NaN
# 3                                     NaN                               NaN
# 4                                     NaN                               NaN
#
#    INQUISIT_delay_v2___values.t4_ip_found  INQUISIT_delay_v2___values.t4_ip  \
# 0                                     NaN                               NaN
# 1                                     NaN                               NaN
# 2                                     NaN                               NaN
# 3                                     NaN                               NaN
# 4                                     NaN                               NaN
#
#    INQUISIT_delay_v2___values.t5_ip_found  INQUISIT_delay_v2___values.t5_ip  \
# 0                                     NaN                               NaN
# 1                                     NaN                               NaN
# 2                                     NaN                               NaN
# 3                                     NaN                               NaN
# 4                                     NaN                               NaN
#
#    INQUISIT_delay_v2___values.p1_ip_found  INQUISIT_delay_v2___values.p1_ip  \
# 0                                     NaN                               NaN
# 1                                     NaN                               NaN
# 2                                     NaN                               NaN
# 3                                     NaN                               NaN
# 4                                     NaN                               NaN
#
#    INQUISIT_delay_v2___values.p2_ip_found  INQUISIT_delay_v2___values.p2_ip  \
# 0                                     NaN                               NaN
# 1                                     NaN                               NaN
# 2                                     NaN                               NaN
# 3                                     NaN                               NaN
# 4                                     NaN                               NaN
#
#    INQUISIT_delay_v2___values.p3_ip_found  INQUISIT_delay_v2___values.p3_ip  \
# 0                                     NaN                               NaN
# 1                                     NaN                               NaN
# 2                                     NaN                               NaN
# 3                                     NaN                               NaN
# 4                                     NaN                               NaN
#
#    INQUISIT_delay_v2___values.p4_ip_found INQUISIT_delay_v2___values.p4_ip  \
# 0                                     NaN                              NaN
# 1                                     NaN                              NaN
# 2                                     NaN                              NaN
# 3                                     NaN                              NaN
# 4                                     NaN                              NaN
#
#   INQUISIT_delay_v2___values.p5_ip_found  INQUISIT_delay_v2___values.p5_ip  \
# 0                                    NaN                               NaN
# 1                                    NaN                               NaN
# 2                                    NaN                               NaN
# 3                                    NaN                               NaN
# 4                                    NaN                               NaN
#
#    INQUISIT_delay_v2___text.subjectquestion.currentitem  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   INQUISIT_delay_v2___text.subjectanswer.currentitem  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    INQUISIT_gonogo___script.startdate INQUISIT_gonogo___script.starttime  \
# 0                                 NaN                                NaN
# 1                             90717.0                           11:08:38
# 2                             41317.0                           16:09:10
# 3                             41817.0                           18:14:19
# 4                             90617.0                           15:23:37
#
#    INQUISIT_gonogo___script.elapsedtime  INQUISIT_gonogo___computer.platform  \
# 0                                   NaN                                  NaN
# 1                                791194                                  win
# 2                               0:00:00                                  win
# 3                               0:00:00                                  win
# 4                                770691                                  win
#
#    INQUISIT_gonogo___values.completed  \
# 0                                 NaN
# 1                                 1.0
# 2                                 1.0
# 3                                 1.0
# 4                                 1.0
#
#    INQUISIT_gonogo___expressions.errorrate  \
# 0                                      NaN
# 1                                    0.000
# 2                                    0.008
# 3                                    0.500
# 4                                    0.004
#
#    INQUISIT_gonogo___expressions.errorrate_gotarget  \
# 0                                               NaN
# 1                                               0.0
# 2                                               0.0
# 3                                               1.0
# 4                                               0.0
#
#    INQUISIT_gonogo___expressions.errorrate_Nogotarget  \
# 0                                                NaN
# 1                                              0.000
# 2                                              0.016
# 3                                              0.000
# 4                                              0.008
#
#    INQUISIT_gonogo___expressions.error_verticalcue  \
# 0                                              NaN
# 1                                            0.000
# 2                                            0.008
# 3                                            0.800
# 4                                            0.000
#
#    INQUISIT_gonogo___expressions.error_horizontalcue  \
# 0                                                NaN
# 1                                              0.000
# 2                                              0.008
# 3                                              0.200
# 4                                              0.008
#
#    INQUISIT_gonogo___expressions.omissionerror_v  \
# 0                                            NaN
# 1                                            0.0
# 2                                            0.0
# 3                                            1.0
# 4                                            0.0
#
#    INQUISIT_gonogo___expressions.inhibitionerror_v  \
# 0                                              NaN
# 1                                             0.00
# 2                                             0.04
# 3                                             0.00
# 4                                             0.00
#
#    INQUISIT_gonogo___expressions.omissionerror_h  \
# 0                                            NaN
# 1                                            0.0
# 2                                            0.0
# 3                                            1.0
# 4                                            0.0
#
#    INQUISIT_gonogo___expressions.inhibitionerror_h  \
# 0                                              NaN
# 1                                             0.00
# 2                                             0.01
# 3                                             0.00
# 4                                             0.01
#
#    INQUISIT_gonogo___expressions.meanrt  \
# 0                                   NaN
# 1                               285.712
# 2                               300.712
# 3                                   NaN
# 4                               349.032
#
#    INQUISIT_gonogo___expressions.meanrt_verticalcue_gotarget  \
# 0                                                NaN
# 1                                             285.21
# 2                                             301.02
# 3                                                NaN
# 4                                             348.69
#
#    INQUISIT_gonogo___expressions.meanrt_horizontalcue_gotarget
# 0                                                NaN
# 1                                             287.72
# 2                                             299.48
# 3                                                NaN
# 4                                             350.40
#
# [5 rows x 126 columns]

# %%
inquisit_merge.shape
# Out:
# (103, 126)

# %%
#os.chdir('/home/wraikes/Programming/Partnership/dmt/merged_data/')
os.chdir(r'H:\Documents\Python Scripts\dmt\partnership\merged_data')
inquisit_merge.to_csv('FINAL_INQUISIT.csv')
